# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
 
# %config Completer.use_jedi = False
# %matplotlib inline

# %%
df = pd.read_csv('No_Outliers_v2.csv', index_col=0)

# %%
df.T
# Out:
#                                                             1      \
# Interaction                  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# City                                                  Point Baker
# State                                                          AK
# County                                      Prince of Wales-Hyder
# Zip                                                         99927
# Lat                                                        56.251
# Lng                                                    -133.37571
# Population                                                     38
# Area                                                        Urban
# Timezone                                            America/Sitka
# Job                             Environmental health practitioner
# Children                                                      2.0
# Age                                                          68.0
# Education                                         Master's Degree
# Employment                                              Part Time
# Income                                                   28561.99
# Marital                                                   Widowed
# Gender                                                       Male
# Churn                                                          No
# Outage_sec_perweek                                       6.972566
# Email                                                          10
# Contacts                                                        0
# Yearly_equip_failure                                            1
# Techie                                                          1
# Contract                                                 One year
# Port_modem                                                    Yes
# Tablet                                                        Yes
# InternetService                                       Fiber Optic
# Phone                                                           2
# Multiple                                                       No
# OnlineSecurity                                                Yes
# OnlineBackup                                                  Yes
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                    No
# StreamingMovies                                               Yes
# PaperlessBilling                                              Yes
# PaymentMethod                             Credit Card (automatic)
# Tenure                                                   6.795513
# MonthlyCharge                                          171.449762
# Bandwidth_GB_Year                                       904.53611
# item1                                                           5
# item2                                                           5
# item3                                                           5
# item4                                                           3
# item5                                                           4
# item6                                                           4
# item7                                                           3
# item8                                                           4
# ChildrenIsMissing                                            True
# AgeIs_missing                                               False
# IncomeIs_Missing                                            False
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             2      \
# Interaction                  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# City                                                  West Branch
# State                                                          MI
# County                                                     Ogemaw
# Zip                                                         48661
# Lat                                                      44.32893
# Lng                                                      -84.2408
# Population                                                  10446
# Area                                                        Urban
# Timezone                                          America/Detroit
# Job                                        Programmer, multimedia
# Children                                                      1.0
# Age                                                          27.0
# Education                             Regular High School Diploma
# Employment                                                Retired
# Income                                                   21704.77
# Marital                                                   Married
# Gender                                                     Female
# Churn                                                         Yes
# Outage_sec_perweek                                      12.014541
# Email                                                          12
# Contacts                                                        0
# Yearly_equip_failure                                            1
# Techie                                                          2
# Contract                                           Month-to-month
# Port_modem                                                     No
# Tablet                                                        Yes
# InternetService                                       Fiber Optic
# Phone                                                           2
# Multiple                                                      Yes
# OnlineSecurity                                                Yes
# OnlineBackup                                                   No
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                   Yes
# StreamingMovies                                               Yes
# PaperlessBilling                                              Yes
# PaymentMethod                            Bank Transfer(automatic)
# Tenure                                                   1.156681
# MonthlyCharge                                          242.948015
# Bandwidth_GB_Year                                      800.982766
# item1                                                           3
# item2                                                           4
# item3                                                           3
# item4                                                           3
# item5                                                           4
# item6                                                           3
# item7                                                           4
# item8                                                           4
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                            False
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             3      \
# Interaction                  344d114c-3736-4be5-98f7-c72c281e2d35
# City                                                      Yamhill
# State                                                          OR
# County                                                    Yamhill
# Zip                                                         97148
# Lat                                                      45.35589
# Lng                                                    -123.24657
# Population                                                   3735
# Area                                                        Urban
# Timezone                                      America/Los_Angeles
# Job                                       Chief Financial Officer
# Children                                                      4.0
# Age                                                          50.0
# Education                             Regular High School Diploma
# Employment                                                Student
# Income                                               36028.798176
# Marital                                                   Widowed
# Gender                                                     Female
# Churn                                                          No
# Outage_sec_perweek                                      10.245616
# Email                                                           9
# Contacts                                                        0
# Yearly_equip_failure                                            1
# Techie                                                          2
# Contract                                                 Two Year
# Port_modem                                                    Yes
# Tablet                                                         No
# InternetService                                               DSL
# Phone                                                           2
# Multiple                                                      Yes
# OnlineSecurity                                                 No
# OnlineBackup                                                   No
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                    No
# StreamingMovies                                               Yes
# PaperlessBilling                                              Yes
# PaymentMethod                             Credit Card (automatic)
# Tenure                                                  15.754144
# MonthlyCharge                                          159.440398
# Bandwidth_GB_Year                                     2054.706961
# item1                                                           4
# item2                                                           4
# item3                                                           2
# item4                                                           4
# item5                                                           4
# item6                                                           3
# item7                                                           3
# item8                                                           3
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                             True
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             4      \
# Interaction                  abfa2b40-2d43-4994-b15a-989b8c79e311
# City                                                      Del Mar
# State                                                          CA
# County                                                  San Diego
# Zip                                                         92014
# Lat                                                      32.96687
# Lng                                                    -117.24798
# Population                                                  13863
# Area                                                     Suburban
# Timezone                                      America/Los_Angeles
# Job                                                     Solicitor
# Children                                                      1.0
# Age                                                          48.0
# Education                                        Doctorate Degree
# Employment                                                Retired
# Income                                                   18925.23
# Marital                                                   Married
# Gender                                                       Male
# Churn                                                          No
# Outage_sec_perweek                                      15.206193
# Email                                                          15
# Contacts                                                        2
# Yearly_equip_failure                                            0
# Techie                                                          2
# Contract                                                 Two Year
# Port_modem                                                     No
# Tablet                                                         No
# InternetService                                               DSL
# Phone                                                           2
# Multiple                                                       No
# OnlineSecurity                                                Yes
# OnlineBackup                                                   No
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                   Yes
# StreamingMovies                                                No
# PaperlessBilling                                              Yes
# PaymentMethod                                        Mailed Check
# Tenure                                                  17.087227
# MonthlyCharge                                          120.249493
# Bandwidth_GB_Year                                     2164.579412
# item1                                                           4
# item2                                                           4
# item3                                                           4
# item4                                                           2
# item5                                                           5
# item6                                                           4
# item7                                                           3
# item8                                                           3
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                            False
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             5      \
# Interaction                  68a861fd-0d20-4e51-a587-8a90407ee574
# City                                                    Needville
# State                                                          TX
# County                                                  Fort Bend
# Zip                                                         77461
# Lat                                                      29.38012
# Lng                                                     -95.80673
# Population                                                  11352
# Area                                                     Suburban
# Timezone                                          America/Chicago
# Job                                           Medical illustrator
# Children                                                      0.0
# Age                                                          83.0
# Education                                         Master's Degree
# Employment                                                Student
# Income                                                   40074.19
# Marital                                                 Separated
# Gender                                                       Male
# Churn                                                         Yes
# Outage_sec_perweek                                       8.960316
# Email                                                          16
# Contacts                                                        2
# Yearly_equip_failure                                            1
# Techie                                                          1
# Contract                                           Month-to-month
# Port_modem                                                    Yes
# Tablet                                                         No
# InternetService                                       Fiber Optic
# Phone                                                           1
# Multiple                                                       No
# OnlineSecurity                                                 No
# OnlineBackup                                                   No
# DeviceProtection                                               No
# TechSupport                                                     2
# StreamingTV                                                   Yes
# StreamingMovies                                                No
# PaperlessBilling                                               No
# PaymentMethod                                        Mailed Check
# Tenure                                                   1.670972
# MonthlyCharge                                          150.761216
# Bandwidth_GB_Year                                      271.493436
# item1                                                           4
# item2                                                           4
# item3                                                           4
# item4                                                           3
# item5                                                           4
# item6                                                           4
# item7                                                           4
# item8                                                           5
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                            False
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             6      \
# Interaction                  2b451d12-6c2b-4cea-a295-ba1d6bced078
# City                                                  Fort Valley
# State                                                          GA
# County                                                      Peach
# Zip                                                         31030
# Lat                                                      32.57032
# Lng                                                      -83.8904
# Population                                                  17701
# Area                                                        Urban
# Timezone                                         America/New_York
# Job                                      Chief Technology Officer
# Children                                                      3.0
# Age                                                          83.0
# Education                                  No Schooling Completed
# Employment                                              Full Time
# Income                                               36028.798176
# Marital                                             Never Married
# Gender                                                     Female
# Churn                                                          No
# Outage_sec_perweek                                       7.814859
# Email                                                          15
# Contacts                                                        3
# Yearly_equip_failure                                            1
# Techie                                                          1
# Contract                                                 One year
# Port_modem                                                    Yes
# Tablet                                                         No
# InternetService                                              None
# Phone                                                           2
# Multiple                                                      Yes
# OnlineSecurity                                                Yes
# OnlineBackup                                                  Yes
# DeviceProtection                                              Yes
# TechSupport                                                     1
# StreamingTV                                                    No
# StreamingMovies                                               Yes
# PaperlessBilling                                               No
# PaymentMethod                                    Electronic Check
# Tenure                                                   7.000994
# MonthlyCharge                                          184.401558
# Bandwidth_GB_Year                                     1039.357983
# item1                                                           3
# item2                                                           3
# item3                                                           3
# item4                                                           2
# item5                                                           4
# item6                                                           3
# item7                                                           3
# item8                                                           3
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                             True
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             7      \
# Interaction                  6630d501-838c-4be4-a59c-6f58c814ed6a
# City                                                      Pioneer
# State                                                          TN
# County                                                      Scott
# Zip                                                         37847
# Lat                                                       36.4342
# Lng                                                     -84.27892
# Population                                                   2535
# Area                                                     Suburban
# Timezone                                         America/New_York
# Job                                        Surveyor, hydrographic
# Children                                                      0.0
# Age                                                          53.0
# Education                                      Associate's Degree
# Employment                                              Full Time
# Income                                                    11467.5
# Marital                                                   Widowed
# Gender                                                       Male
# Churn                                                         Yes
# Outage_sec_perweek                                      11.129094
# Email                                                          10
# Contacts                                                        0
# Yearly_equip_failure                                            1
# Techie                                                          2
# Contract                                           Month-to-month
# Port_modem                                                     No
# Tablet                                                         No
# InternetService                                               DSL
# Phone                                                           2
# Multiple                                                       No
# OnlineSecurity                                                 No
# OnlineBackup                                                   No
# DeviceProtection                                               No
# TechSupport                                                     2
# StreamingTV                                                   Yes
# StreamingMovies                                               Yes
# PaperlessBilling                                               No
# PaymentMethod                                    Electronic Check
# Tenure                                                  13.236774
# MonthlyCharge                                          200.064886
# Bandwidth_GB_Year                                     1907.242972
# item1                                                           6
# item2                                                           5
# item3                                                           6
# item4                                                           4
# item5                                                           1
# item6                                                           5
# item7                                                           5
# item8                                                           5
# ChildrenIsMissing                                           False
# AgeIs_missing                                                True
# IncomeIs_Missing                                            False
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             8      \
# Interaction                  70ddaa89-b726-49dc-9022-2d655e4c7936
# City                                                Oklahoma City
# State                                                          OK
# County                                                   Oklahoma
# Zip                                                         73109
# Lat                                                      35.43313
# Lng                                                     -97.52463
# Population                                                  23144
# Area                                                     Suburban
# Timezone                                          America/Chicago
# Job                             Sales promotion account executive
# Children                                                      2.0
# Age                                                          53.0
# Education                                       Bachelor's Degree
# Employment                                              Full Time
# Income                                                   26759.64
# Marital                                                   Married
# Gender                                                     Female
# Churn                                                         Yes
# Outage_sec_perweek                                       7.594838
# Email                                                          16
# Contacts                                                        0
# Yearly_equip_failure                                            0
# Techie                                                          2
# Contract                                           Month-to-month
# Port_modem                                                     No
# Tablet                                                         No
# InternetService                                               DSL
# Phone                                                           1
# Multiple                                                       No
# OnlineSecurity                                                 No
# OnlineBackup                                                  Yes
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                    No
# StreamingMovies                                                No
# PaperlessBilling                                              Yes
# PaymentMethod                                        Mailed Check
# Tenure                                                      37.78
# MonthlyCharge                                          114.754111
# Bandwidth_GB_Year                                      979.612708
# item1                                                           2
# item2                                                           2
# item3                                                           2
# item4                                                           5
# item5                                                           2
# item6                                                           3
# item7                                                           4
# item8                                                           5
# ChildrenIsMissing                                           False
# AgeIs_missing                                                True
# IncomeIs_Missing                                            False
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                            True
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             9      \
# Interaction                  05a49ee3-8fd5-453a-a5f3-82b6cd986856
# City                                                  Saint Cloud
# State                                                          FL
# County                                                    Osceola
# Zip                                                         34771
# Lat                                                      28.27646
# Lng                                                     -81.16273
# Population                                                  17351
# Area                                                     Suburban
# Timezone                                         America/New_York
# Job                                Teaching laboratory technician
# Children                                                      2.0
# Age                                                          49.0
# Education                          Some College, Less than 1 Year
# Employment                                              Full Time
# Income                                                   58634.51
# Marital                                                 Separated
# Gender                                       Prefer not to answer
# Churn                                                          No
# Outage_sec_perweek                                       6.637259
# Email                                                          20
# Contacts                                                        2
# Yearly_equip_failure                                            3
# Techie                                                          0
# Contract                                           Month-to-month
# Port_modem                                                    Yes
# Tablet                                                         No
# InternetService                                               DSL
# Phone                                                           2
# Multiple                                                       No
# OnlineSecurity                                                Yes
# OnlineBackup                                                  Yes
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                    No
# StreamingMovies                                                No
# PaperlessBilling                                              Yes
# PaymentMethod                            Bank Transfer(automatic)
# Tenure                                                   8.220686
# MonthlyCharge                                          118.366844
# Bandwidth_GB_Year                                     1312.874964
# item1                                                           5
# item2                                                           4
# item3                                                           4
# item4                                                           3
# item5                                                           4
# item6                                                           3
# item7                                                           4
# item8                                                           4
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                            False
# Techieis_missing                                             True
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             10     ...  \
# Interaction                  86f17e4d-2c24-4b70-a6ec-dddf0609dbaa  ...
# City                                                   Cincinnati  ...
# State                                                          OH  ...
# County                                                   Hamilton  ...
# Zip                                                         45237  ...
# Lat                                                      39.19296  ...
# Lng                                                      -84.4523  ...
# Population                                                  20193  ...
# Area                                                        Rural  ...
# Timezone                                         America/New_York  ...
# Job                                      Museum education officer  ...
# Children                                                      2.0  ...
# Age                                                          86.0  ...
# Education                           GED or Alternative Credential  ...
# Employment                                              Full Time  ...
# Income                                                    50231.4  ...
# Marital                                                   Married  ...
# Gender                                                     Female  ...
# Churn                                                          No  ...
# Outage_sec_perweek                                       9.230409  ...
# Email                                                          18  ...
# Contacts                                                        1  ...
# Yearly_equip_failure                                            0  ...
# Techie                                                          0  ...
# Contract                                                 Two Year  ...
# Port_modem                                                    Yes  ...
# Tablet                                                         No  ...
# InternetService                                       Fiber Optic  ...
# Phone                                                           2  ...
# Multiple                                                       No  ...
# OnlineSecurity                                                Yes  ...
# OnlineBackup                                                   No  ...
# DeviceProtection                                              Yes  ...
# TechSupport                                                     0  ...
# StreamingTV                                                    No  ...
# StreamingMovies                                               Yes  ...
# PaperlessBilling                                              Yes  ...
# PaymentMethod                                        Mailed Check  ...
# Tenure                                                   3.422086  ...
# MonthlyCharge                                           163.00528  ...
# Bandwidth_GB_Year                                      508.763791  ...
# item1                                                           2  ...
# item2                                                           2  ...
# item3                                                           2  ...
# item4                                                           2  ...
# item5                                                           5  ...
# item6                                                           2  ...
# item7                                                           3  ...
# item8                                                           3  ...
# ChildrenIsMissing                                            True  ...
# AgeIs_missing                                               False  ...
# IncomeIs_Missing                                            False  ...
# Techieis_missing                                             True  ...
# Phoneis_missing                                             False  ...
# TechSupportis_missing                                        True  ...
# Tenure_is_missing                                           False  ...
# Bandwidth_GB_YearIs_missing                                 False  ...
#
#                                                             9991   \
# Interaction                  89d0d064-307e-4f21-a5b4-6ec1137c8bfc
# City                                                 Gilmore City
# State                                                          IA
# County                                                   Humboldt
# Zip                                                         50541
# Lat                                                      42.71548
# Lng                                                     -94.44913
# Population                                                    836
# Area                                                        Rural
# Timezone                                          America/Chicago
# Job                                                   Tax adviser
# Children                                                      2.0
# Age                                                          68.0
# Education                                      Associate's Degree
# Employment                                                Student
# Income                                               36028.798176
# Marital                                                  Divorced
# Gender                                                       Male
# Churn                                                          No
# Outage_sec_perweek                                       12.88362
# Email                                                          11
# Contacts                                                        1
# Yearly_equip_failure                                            0
# Techie                                                          0
# Contract                                           Month-to-month
# Port_modem                                                    Yes
# Tablet                                                         No
# InternetService                                       Fiber Optic
# Phone                                                           2
# Multiple                                                      Yes
# OnlineSecurity                                                 No
# OnlineBackup                                                  Yes
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                   Yes
# StreamingMovies                                                No
# PaperlessBilling                                               No
# PaymentMethod                            Bank Transfer(automatic)
# Tenure                                                   63.63416
# MonthlyCharge                                            191.4358
# Bandwidth_GB_Year                                        5590.206
# item1                                                           1
# item2                                                           1
# item3                                                           1
# item4                                                           3
# item5                                                           4
# item6                                                           2
# item7                                                           3
# item8                                                           1
# ChildrenIsMissing                                            True
# AgeIs_missing                                               False
# IncomeIs_Missing                                             True
# Techieis_missing                                             True
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             9992   \
# Interaction                  24f1d865-3d58-495f-9dc9-b5927a1fd40a
# City                                                       Smyrna
# State                                                          NY
# County                                                   Chenango
# Zip                                                         13464
# Lat                                                      42.68582
# Lng                                                     -75.61754
# Population                                                   1378
# Area                                                        Rural
# Timezone                                         America/New_York
# Job                                                    Translator
# Children                                                      0.0
# Age                                                          52.0
# Education                                      Associate's Degree
# Employment                                              Full Time
# Income                                                   30724.26
# Marital                                                  Divorced
# Gender                                                       Male
# Churn                                                          No
# Outage_sec_perweek                                       11.16505
# Email                                                          11
# Contacts                                                        3
# Yearly_equip_failure                                            0
# Techie                                                          1
# Contract                                                 One year
# Port_modem                                                     No
# Tablet                                                        Yes
# InternetService                                       Fiber Optic
# Phone                                                           2
# Multiple                                                       No
# OnlineSecurity                                                Yes
# OnlineBackup                                                  Yes
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                   Yes
# StreamingMovies                                                No
# PaperlessBilling                                               No
# PaymentMethod                             Credit Card (automatic)
# Tenure                                                   55.49816
# MonthlyCharge                                             163.501
# Bandwidth_GB_Year                                        4948.485
# item1                                                           3
# item2                                                           3
# item3                                                           2
# item4                                                           2
# item5                                                           5
# item6                                                           4
# item7                                                           4
# item8                                                           2
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                            False
# ...
#
#                                                             9997   \
# Interaction                  6e96b921-0c09-4993-bbda-a1ac6411061a
# City                                                  Clarksville
# State                                                          TN
# County                                                 Montgomery
# Zip                                                         37042
# Lat                                                      36.56907
# Lng                                                     -87.41694
# Population                                                  77168
# Area                                                        Rural
# Timezone                                          America/Chicago
# Job                                     Consulting civil engineer
# Children                                                      4.0
# Age                                                          48.0
# Education                             Regular High School Diploma
# Employment                                              Part Time
# Income                                               36028.798176
# Marital                                                  Divorced
# Gender                                                       Male
# Churn                                                          No
# Outage_sec_perweek                                       8.115849
# Email                                                          15
# Contacts                                                        2
# Yearly_equip_failure                                            0
# Techie                                                          0
# Contract                                                 Two Year
# Port_modem                                                     No
# Tablet                                                         No
# InternetService                                       Fiber Optic
# Phone                                                           0
# Multiple                                                      Yes
# OnlineSecurity                                                Yes
# OnlineBackup                                                  Yes
# DeviceProtection                                              Yes
# TechSupport                                                     1
# StreamingTV                                                   Yes
# StreamingMovies                                                No
# PaperlessBilling                                               No
# PaymentMethod                                    Electronic Check
# Tenure                                                   61.04037
# MonthlyCharge                                            208.8564
# Bandwidth_GB_Year                                        5695.952
# item1                                                           4
# item2                                                           5
# item3                                                           5
# item4                                                           4
# item5                                                           4
# item6                                                           5
# item7                                                           2
# item8                                                           5
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                             True
# Techieis_missing                                             True
# Phoneis_missing                                              True
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             9998   \
# Interaction                  e8307ddf-9a01-4fff-bc59-4742e03fd24f
# City                                                     Mobeetie
# State                                                          TX
# County                                                    Wheeler
# Zip                                                         79061
# Lat                                                      35.52039
# Lng                                                     -100.4418
# Population                                                    406
# Area                                                        Rural
# Timezone                                          America/Chicago
# Job                                  IT technical support officer
# Children                                                      2.0
# Age                                                          53.0
# Education                             Nursery School to 8th Grade
# Employment                                              Full Time
# Income                                               36028.798176
# Marital                                             Never Married
# Gender                                                     Female
# Churn                                                          No
# Outage_sec_perweek                                       4.837696
# Email                                                          10
# Contacts                                                        0
# Yearly_equip_failure                                            0
# Techie                                                          1
# Contract                                           Month-to-month
# Port_modem                                                     No
# Tablet                                                         No
# InternetService                                       Fiber Optic
# Phone                                                           2
# Multiple                                                      Yes
# OnlineSecurity                                                Yes
# OnlineBackup                                                  Yes
# DeviceProtection                                               No
# TechSupport                                                     1
# StreamingTV                                                    No
# StreamingMovies                                                No
# PaperlessBilling                                              Yes
# PaymentMethod                            Bank Transfer(automatic)
# Tenure                                                      37.78
# MonthlyCharge                                            168.2209
# Bandwidth_GB_Year                                        4159.306
# item1                                                           4
# item2                                                           4
# item3                                                           4
# item4                                                           4
# item5                                                           4
# item6                                                           4
# item7                                                           4
# item8                                                           5
# ChildrenIsMissing                                            True
# AgeIs_missing                                                True
# IncomeIs_Missing                                             True
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                            True
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             9999   \
# Interaction                  3775ccfc-0052-4107-81ae-9657f81ecdf3
# City                                                   Carrollton
# State                                                          GA
# County                                                    Carroll
# Zip                                                         30117
# Lat                                                      33.58016
# Lng                                                     -85.13241
# Population                                                  35575
# Area                                                        Urban
# Timezone                                         America/New_York
# Job                                                Water engineer
# Children                                                      1.0
# Age                                                          39.0
# Education                                       Bachelor's Degree
# Employment                                              Full Time
# Income                                                   16667.58
# Marital                                                 Separated
# Gender                                                       Male
# Churn                                                          No
# Outage_sec_perweek                                       12.07646
# Email                                                          14
# Contacts                                                        1
# Yearly_equip_failure                                            0
# Techie                                                          1
# Contract                                                 Two Year
# Port_modem                                                     No
# Tablet                                                        Yes
# InternetService                                       Fiber Optic
# Phone                                                           1
# Multiple                                                      Yes
# OnlineSecurity                                                 No
# OnlineBackup                                                   No
# DeviceProtection                                               No
# TechSupport                                                     2
# StreamingTV                                                   Yes
# StreamingMovies                                               Yes
# PaperlessBilling                                              Yes
# PaymentMethod                             Credit Card (automatic)
# Tenure                                                    71.0956
# MonthlyCharge                                            252.6286
# Bandwidth_GB_Year                                        6468.457
# item1                                                           4
# item2                                                           4
# item3                                                           6
# item4                                                           4
# item5                                                           3
# item6                                                           3
# item7                                                           5
# item8                                                           4
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                            False
# Techieis_missing                                            False
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
#                                                             10000
# Interaction                  9de5fb6e-bd33-4995-aec8-f01d0172a499
# City                                                 Clarkesville
# State                                                          GA
# County                                                  Habersham
# Zip                                                         30523
# Lat                                                      34.70783
# Lng                                                     -83.53648
# Population                                                  12230
# Area                                                        Urban
# Timezone                                         America/New_York
# Job                                            Personal assistant
# Children                                                      1.0
# Age                                                          28.0
# Education                           GED or Alternative Credential
# Employment                                              Full Time
# Income                                               36028.798176
# Marital                                             Never Married
# Gender                                                       Male
# Churn                                                          No
# Outage_sec_perweek                                       12.64176
# Email                                                          17
# Contacts                                                        1
# Yearly_equip_failure                                            0
# Techie                                                          0
# Contract                                           Month-to-month
# Port_modem                                                    Yes
# Tablet                                                         No
# InternetService                                       Fiber Optic
# Phone                                                           2
# Multiple                                                      Yes
# OnlineSecurity                                                Yes
# OnlineBackup                                                  Yes
# DeviceProtection                                              Yes
# TechSupport                                                     1
# StreamingTV                                                    No
# StreamingMovies                                               Yes
# PaperlessBilling                                              Yes
# PaymentMethod                                    Electronic Check
# Tenure                                                   63.35086
# MonthlyCharge                                             218.371
# Bandwidth_GB_Year                                        5857.586
# item1                                                           2
# item2                                                           2
# item3                                                           3
# item4                                                           3
# item5                                                           3
# item6                                                           3
# item7                                                           4
# item8                                                           1
# ChildrenIsMissing                                           False
# AgeIs_missing                                               False
# IncomeIs_Missing                                             True
# Techieis_missing                                             True
# Phoneis_missing                                             False
# TechSupportis_missing                                       False
# Tenure_is_missing                                           False
# Bandwidth_GB_YearIs_missing                                 False
#
# [57 rows x 9775 columns]

# %%
df['Churn'].replace({
    'No': 0,
    'Yes': 1
}, inplace=True)

# %% [markdown]
# # PCA works best with continous varibles

# %%
pca_df = df.loc[:,['Age', 'Income', 'Outage_sec_perweek', 'Tenure',
          'MonthlyCharge', 'Bandwidth_GB_Year', 'Population']]

# %%
pca_df.columns
# Out:
# Index(['Age', 'Income', 'Outage_sec_perweek', 'Tenure', 'MonthlyCharge',
#        'Bandwidth_GB_Year', 'Population'],
#       dtype='object')

# %%
standard_scaler = StandardScaler()
pca_df = standard_scaler.fit_transform(pca_df)

# %%
pca_df
# Out:
# array([[ 0.82199527, -0.41645219, -0.9396258 , ..., -0.05975996,
#         -1.20193711, -0.67204807],
#        [-1.45394244, -0.74770002,  0.39494906, ...,  1.59021989,
#         -1.25187643,  0.04855026],
#        [-0.17719689, -0.05575734, -0.0732729 , ..., -0.33690251,
#         -0.6472593 , -0.41608611],
#        ...,
#        [-0.01066486, -0.05575734, -1.50471071, ..., -0.13427307,
#          0.36769807, -0.64656957],
#        [-0.78781433, -0.99102869,  0.41133856, ...,  1.81362072,
#          1.48130204,  1.78835765],
#        [-1.39843176, -0.05575734,  0.56096944, ...,  1.02305107,
#          1.18670529,  0.17206558]])

# %%
normalised_df = pd.DataFrame(data=pca_df,
                            columns=['Age', 'Income', 'Outage_sec_perweek', 'Tenure',
                                    'Monthly_Charge', 'Bandwidth_GB', 'Population'])

# %%
normalised_df
# Out:
#            Age    Income  Outage_sec_perweek    Tenure  Monthly_Charge  \
# 0     0.821995 -0.416452           -0.939626 -1.096668       -0.059760
# 1    -1.453942 -0.747700            0.394949 -1.320241        1.590220
# 2    -0.177197 -0.055757           -0.073273 -0.741468       -0.336903
# 3    -0.288218 -0.881970            1.239757 -0.688613       -1.241319
# 4     1.654655  0.139661           -0.413482 -1.299850       -0.537194
# ...        ...       ...                 ...       ...             ...
# 9770 -0.010665  0.895635           -0.332731  1.337839       -0.327939
# 9771 -0.288218 -0.055757           -0.637007  1.054081        0.803481
# 9772 -0.010665 -0.055757           -1.504711  0.131833       -0.134273
# 9773 -0.787814 -0.991029            0.411339  1.452760        1.813621
# 9774 -1.398432 -0.055757            0.560969  1.145690        1.023051
#
#       Bandwidth_GB  Population
# 0        -1.201937   -0.672048
# 1        -1.251876    0.048550
# 2        -0.647259   -0.416086
# 3        -0.594273    0.285126
# 4        -1.507226    0.111277
# ...            ...         ...
# 9770      1.501941   -0.630369
# 9771      1.108756    4.668051
# 9772      0.367698   -0.646570
# 9773      1.481302    1.788358
# 9774      1.186705    0.172066
#
# [9775 rows x 7 columns]

# %%
pca = PCA()
pca.fit(normalised_df)
# Out:
# PCA()

# %%
loadings = pd.DataFrame(pca.components_, columns=normalised_df.columns)

# %%
loadings
# Out:
#         Age    Income  Outage_sec_perweek    Tenure  Monthly_Charge  \
# 0 -0.008266 -0.004960            0.018685  0.705324        0.044492
# 1 -0.050681 -0.095804            0.701401 -0.059409        0.700821
# 2  0.364172 -0.688088           -0.075085  0.005718        0.043211
# 3 -0.883270 -0.075406            0.052271 -0.017356       -0.102425
# 4  0.259755  0.713610            0.075707  0.002510        0.077261
# 5 -0.127640  0.049054           -0.702544 -0.037858        0.697251
# 6  0.028473 -0.000706           -0.004312 -0.705134       -0.048830
#
#    Bandwidth_GB  Population
# 0      0.707174    0.000901
# 1     -0.004584   -0.039867
# 2     -0.007799    0.621542
# 3      0.010949    0.447776
# 4     -0.002141    0.641543
# 5      0.011310   -0.003762
# 6      0.706803    0.000765

# %%
def abline(slope, intercept, ax):
    '''
    Calculates coordinates of a lined based on slope and intercept 
    '''
    x_vals = np.array(ax.get_xlim())
    return (x_vals, intercept + slope * x_vals)

# %%
ax = normalised_df.plot.scatter(x='Tenure', y='Bandwidth_GB', alpha=0.3,
                               figsize = (4,4))

ax.set_xlim(-3,3)
ax.set_ylim(-3,3)

ax.plot(*abline(loadings.loc[0, 'Tenure'] / loadings.loc[0, 'Bandwidth_GB'],
               intercept=0, ax=ax),
       c= 'C1', ls= '--')

ax.plot(*abline(loadings.loc[1, 'Tenure'] / loadings.loc[1, 'Bandwidth_GB'],
               0, ax),
       ls = '--', c = 'C1')

plt.tight_layout()
plt.show()

# %%
normalised_df
# Out:
#            Age    Income  Outage_sec_perweek    Tenure  Monthly_Charge  \
# 0     0.821995 -0.416452           -0.939626 -1.096668       -0.059760
# 1    -1.453942 -0.747700            0.394949 -1.320241        1.590220
# 2    -0.177197 -0.055757           -0.073273 -0.741468       -0.336903
# 3    -0.288218 -0.881970            1.239757 -0.688613       -1.241319
# 4     1.654655  0.139661           -0.413482 -1.299850       -0.537194
# ...        ...       ...                 ...       ...             ...
# 9770 -0.010665  0.895635           -0.332731  1.337839       -0.327939
# 9771 -0.288218 -0.055757           -0.637007  1.054081        0.803481
# 9772 -0.010665 -0.055757           -1.504711  0.131833       -0.134273
# 9773 -0.787814 -0.991029            0.411339  1.452760        1.813621
# 9774 -1.398432 -0.055757            0.560969  1.145690        1.023051
#
#       Bandwidth_GB  Population
# 0        -1.201937   -0.672048
# 1        -1.251876    0.048550
# 2        -0.647259   -0.416086
# 3        -0.594273    0.285126
# 4        -1.507226    0.111277
# ...            ...         ...
# 9770      1.501941   -0.630369
# 9771      1.108756    4.668051
# 9772      0.367698   -0.646570
# 9773      1.481302    1.788358
# 9774      1.186705    0.172066
#
# [9775 rows x 7 columns]

# %% [markdown]
# # interpreting PCA

# %%
sp_pca = PCA()
sp_pca.fit(normalised_df)
# Out:
# PCA()

# %%
sp_pca.explained_variance_ratio_ * 100
# Out:
# array([27.05605414, 15.75791597, 14.41820504, 14.31375727, 14.14205275,
#        12.80974596,  1.50226887])

# %% [markdown]
# ##  5 components expressed 99 percent
# #### We can consider eliminating PCA5

# %%
explained_variance = pd.DataFrame(sp_pca.explained_variance_ratio_)
ax = explained_variance.head(10).plot.bar(legend=False, figsize=(8,8))
ax.set_xlabel('components')
ax.set_ylabel('Percentage')

plt.tight_layout()
plt.show()

# %%
data_pca = PCA(n_components=5)
data_pca_trans = data_pca.fit_transform(normalised_df)

# %%
data_pca_df = pd.DataFrame(data=data_pca_trans,
                          columns=['PCA1', 'PCA2', 'PCA3', 'PCA4', 'PC5'])
data_pca_df
# Out:
#           PCA1      PCA2      PCA3      PCA4       PC5
# 0    -1.649036 -0.605242  0.239270 -1.032689 -0.590747
# 1    -1.722590  1.619035  0.056448  1.229318 -0.727959
# 2    -0.995693 -0.209574 -0.293027  0.010863 -0.384806
# 3    -0.930999  0.130995  0.533101  0.646143 -0.523831
# 4    -2.028585 -0.684037  0.587800 -1.382746  0.528014
# ...        ...       ...       ...       ...       ...
# 9770  1.980014 -0.609704 -1.005211 -0.330958  0.181571
# 9771  1.558264 -0.117560  2.914724  2.227274  2.894222
# 9772  0.318704 -1.127365 -0.262322 -0.339056 -0.582109
# 9773  2.173622  1.530013  1.550791  1.398113  0.407200
# 9774  1.715281  1.106291 -0.364576  1.234090 -0.170805
#
# [9775 rows x 5 columns]

# %%
# reset index to avoid adding an extra row

# %%
df['Churn']
# Out:
# 1        0
# 2        1
# 3        0
# 4        0
# 5        1
#         ..
# 9996     0
# 9997     0
# 9998     0
# 9999     0
# 10000    0
# Name: Churn, Length: 9775, dtype: int64

# %%
df.reset_index(drop=True, inplace=True)

# %%
print('explained variation per principal components: {}' .format(data_pca.explained_variance_ratio_ * 100))
# Out:
# explained variation per principal components: [27.05605414 15.75791597 14.41820504 14.31375727 14.14205275]

# %%
final_df = pd.concat([data_pca_df, df[['Churn']]], join = 'outer', axis = 1)

# %%
final_df
# Out:
#           PCA1      PCA2      PCA3      PCA4       PC5  Churn
# 0    -1.649036 -0.605242  0.239270 -1.032689 -0.590747      0
# 1    -1.722590  1.619035  0.056448  1.229318 -0.727959      1
# 2    -0.995693 -0.209574 -0.293027  0.010863 -0.384806      0
# 3    -0.930999  0.130995  0.533101  0.646143 -0.523831      0
# 4    -2.028585 -0.684037  0.587800 -1.382746  0.528014      1
# ...        ...       ...       ...       ...       ...    ...
# 9770  1.980014 -0.609704 -1.005211 -0.330958  0.181571      0
# 9771  1.558264 -0.117560  2.914724  2.227274  2.894222      0
# 9772  0.318704 -1.127365 -0.262322 -0.339056 -0.582109      0
# 9773  2.173622  1.530013  1.550791  1.398113  0.407200      0
# 9774  1.715281  1.106291 -0.364576  1.234090 -0.170805      0
#
# [9775 rows x 6 columns]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)

targets = [0, 1]
colors = ["#41bbc5", "#5da13b", 'red']
for target, color in zip(targets, colors):
    indicesToKeep = final_df['Churn'] == target
    plt.scatter(final_df.loc[indicesToKeep, 'PCA1'],
                final_df.loc[indicesToKeep, 'PCA2'],
                 final_df.loc[indicesToKeep, 'PCA3'], lw=6
)
ax.legend(['Yes','No'], fontsize='large')
plt.tight_layout()
plt.show()
# Out:
# /Users/cristophernimatuj/Desktop/Master_folder/jupyter/Jupyter_notebook/env/lib/python3.8/site-packages/matplotlib/collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /Users/cristophernimatuj/Desktop/Master_folder/jupyter/Jupyter_notebook/env/lib/python3.8/site-packages/matplotlib/collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
from yellowbrick.features import PCA

# %%
classes = ['No Churn' '', 'Churn']
vis_3 = PCA(scale=True, projection=3,
           random_state=24,
           colors=["#41bbc5", "#5da13b",], alpha= .2
           , classes=classes)


vis_3.fit_transform(final_df, final_df.Churn)
plt.tight_layout()
vis_3.show()
# Out:
# /Users/cristophernimatuj/Desktop/Master_folder/jupyter/Jupyter_notebook/env/lib/python3.8/site-packages/yellowbrick/features/pca.py:448: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout()
# <Axes3DSubplot:title={'center':'Principal Component Plot'}, xlabel='$PC_1$', ylabel='$PC_2$'>

# %%
classes = ['No Churn' '', 'Churn']
vis_3 = PCA(scale=True, projection=3,
           random_state=2021,
           colors=["#41bbc5", "#5da13b",], alpha= .2
           , classes=classes)


vis_3.fit_transform(final_df, final_df.Churn)
plt.tight_layout()
vis_3.show()
# Out:
# /Users/cristophernimatuj/Desktop/Master_folder/jupyter/Jupyter_notebook/env/lib/python3.8/site-packages/yellowbrick/features/pca.py:448: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout()
# <Axes3DSubplot:title={'center':'Principal Component Plot'}, xlabel='$PC_1$', ylabel='$PC_2$'>

# %%
maxPC = 1.01 * np.max(np.max(np.abs(loadings.loc[0:6, :])))

f, axes = plt.subplots(7, 1, figsize=(7, 8), sharex=True)

for i, ax in enumerate(axes):
    pc_loadings = loadings.loc[i, :]
    colors = ['C0' if l > 0 else 'C1' for l in pc_loadings]
    ax.axhline(color='#888888')
    pc_loadings.plot.bar(ax=ax, color=colors)
    ax.set_ylabel(f'PC{i+1}')
    ax.set_ylim(-maxPC, maxPC)

plt.tight_layout()
plt.show()

# %%
maxPC = 1.01 * np.max(np.max(np.abs(loadings.loc[0:6, :])))

f, axes = plt.subplots(7, 1, figsize=(7, 8), sharex=True)

for i, ax in enumerate(axes):
    pc_loadings = loadings.loc[i, :]
    colors = ['C0' if l > 0 else 'C1' for l in pc_loadings]
    ax.axhline(color='#888888')
    pc_loadings.plot.bar(ax=ax, color=colors)
    ax.set_ylabel(f'PC{i+1}')
    ax.set_ylim(-maxPC, maxPC)

plt.tight_layout()
plt.show()

# %%
df
# Out:
#                                Interaction          City State  \
# 0     aa90260b-4141-4a24-8e36-b04ce1f4f77b   Point Baker    AK
# 1     fb76459f-c047-4a9d-8af9-e0f7d4ac2524   West Branch    MI
# 2     344d114c-3736-4be5-98f7-c72c281e2d35       Yamhill    OR
# 3     abfa2b40-2d43-4994-b15a-989b8c79e311       Del Mar    CA
# 4     68a861fd-0d20-4e51-a587-8a90407ee574     Needville    TX
# ...                                    ...           ...   ...
# 9770  45deb5a2-ae04-4518-bf0b-c82db8dbe4a4   Mount Holly    VT
# 9771  6e96b921-0c09-4993-bbda-a1ac6411061a   Clarksville    TN
# 9772  e8307ddf-9a01-4fff-bc59-4742e03fd24f      Mobeetie    TX
# 9773  3775ccfc-0052-4107-81ae-9657f81ecdf3    Carrollton    GA
# 9774  9de5fb6e-bd33-4995-aec8-f01d0172a499  Clarkesville    GA
#
#                      County    Zip       Lat        Lng  Population      Area  \
# 0     Prince of Wales-Hyder  99927  56.25100 -133.37571          38     Urban
# 1                    Ogemaw  48661  44.32893  -84.24080       10446     Urban
# 2                   Yamhill  97148  45.35589 -123.24657        3735     Urban
# 3                 San Diego  92014  32.96687 -117.24798       13863  Suburban
# 4                 Fort Bend  77461  29.38012  -95.80673       11352  Suburban
# ...                     ...    ...       ...        ...         ...       ...
# 9770                Rutland   5758  43.43391  -72.78734         640     Rural
# 9771             Montgomery  37042  36.56907  -87.41694       77168     Rural
# 9772                Wheeler  79061  35.52039 -100.44180         406     Rural
# 9773                Carroll  30117  33.58016  -85.13241       35575     Urban
# 9774              Habersham  30523  34.70783  -83.53648       12230     Urban
#
#                  Timezone  ... item7  item8  ChildrenIsMissing AgeIs_missing  \
# 0           America/Sitka  ...     3      4               True         False
# 1         America/Detroit  ...     4      4              False         False
# 2     America/Los_Angeles  ...     3      3              False         False
# 3     America/Los_Angeles  ...     3      3              False         False
# 4         America/Chicago  ...     4      5              False         False
# ...                   ...  ...   ...    ...                ...           ...
# 9770     America/New_York  ...     2      3              False          True
# 9771      America/Chicago  ...     2      5              False         False
# 9772      America/Chicago  ...     4      5               True          True
# 9773     America/New_York  ...     5      4              False         False
# 9774     America/New_York  ...     4      1              False         False
#
#      IncomeIs_Missing  Techieis_missing Phoneis_missing TechSupportis_missing  \
# 0               False             False           False                 False
# 1               False             False           False                 False
# 2                True             False           False                 False
# 3               False             False           False                 False
# 4               False             False           False                 False
# ...               ...               ...             ...                   ...
# 9770            False              True            True                 False
# 9771             True              True            True                 False
# 9772             True             False           False                 False
# 9773            False             False           False                 False
# 9774             True              True           False                 False
#
#       Tenure_is_missing  Bandwidth_GB_YearIs_missing
# 0                 False                        False
# 1                 False                        False
# 2                 False                        False
# 3                 False                        False
# 4                 False                        False
# ...                 ...                          ...
# 9770              False                        False
# 9771              False                        False
# 9772               True                        False
# 9773              False                        False
# 9774              False                        False
#
# [9775 rows x 57 columns]
